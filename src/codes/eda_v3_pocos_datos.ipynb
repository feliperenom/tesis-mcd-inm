# %% [markdown]
# ## Importacion de Librerias y Carga de Datos

# %%
# importacion de librerias

import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("datasets/propiedades_scrapeadas_2025-09-08.csv")

df.head(5)
# Out:
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 4  https://www.casasymas.com.uy/propiedad/165019-...  U$S 685.000Venta
#
#   Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0           3    2.0     255 m²                  90m²              255m²
# 1           4    3.0     429 m²                 256m²              429m²
# 2           3    3.0     230 m²                 177m²              230m²
# 3           3    3.0     130 m²                 130m²              150m²
# 4           4    5.0     289 m²                 268m²              811m²
#
#          Dormitorios Servicio        Dormitorios Suite      Garage  \
# 0  Dormitorios de Servicio: 2  Dormitorios en Suite: 1  Cochera: 1
# 1  Dormitorios de Servicio: 1  Dormitorios en Suite: 1   Garaje: 4
# 2                         NaN                      NaN   Garaje: 1
# 3                         NaN  Dormitorios en Suite: 1  Cochera: 1
# 4                         NaN  Dormitorios en Suite: 2  Cochera: 2
#
#    Parrillero    Calefacción Orientación  Plantas            Cocina  \
# 0  Parrillero          Hogar       Oeste      1.0   Cocina Definida
# 1         NaN            NaN         NaN      NaN   Cocina Definida
# 2  Parrillero          Hogar         NaN      2.0   Cocina Definida
# 3  Parrillero  losa radiante       Norte      2.0  Cocina Integrada
# 4  Parrillero     Radiadores        Este      2.0   Cocina Definida
#
#    Año de Construcción  Jardín  Acepta Mascotas Superficie Balcones  \
# 0               1923.0  Jardín              NaN                 NaN
# 1               2005.0  Jardín  Acepta Mascotas                 NaN
# 2               1958.0  Jardín              NaN                40m²
# 3               2024.0  Jardín  Acepta Mascotas                20m²
# 4               1979.0  Jardín              NaN                 NaN
#
#    Propiedad Horizontal Seguridad  Piscina Gastos Comúnes Altura  \
# 0                   NaN       NaN      NaN            NaN    NaN
# 1                   NaN       NaN      NaN            NaN    NaN
# 2                   NaN       NaN      NaN            NaN    NaN
# 3  Propiedad Horizontal   virtual      NaN            NaN    NaN
# 4                   NaN       NaN  Piscina            NaN    NaN
#
#    Aptos por piso Disposición Muebles Patio  Pisos Edificio Lavadero  Piso
# 0             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 1             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 2             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 3             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 4             NaN         NaN     NaN   NaN             NaN      NaN   NaN

# %%
df.head()
# Out:
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 4  https://www.casasymas.com.uy/propiedad/165019-...  U$S 685.000Venta
#
#   Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0           3    2.0     255 m²                  90m²              255m²
# 1           4    3.0     429 m²                 256m²              429m²
# 2           3    3.0     230 m²                 177m²              230m²
# 3           3    3.0     130 m²                 130m²              150m²
# 4           4    5.0     289 m²                 268m²              811m²
#
#          Dormitorios Servicio        Dormitorios Suite      Garage  \
# 0  Dormitorios de Servicio: 2  Dormitorios en Suite: 1  Cochera: 1
# 1  Dormitorios de Servicio: 1  Dormitorios en Suite: 1   Garaje: 4
# 2                         NaN                      NaN   Garaje: 1
# 3                         NaN  Dormitorios en Suite: 1  Cochera: 1
# 4                         NaN  Dormitorios en Suite: 2  Cochera: 2
#
#    Parrillero    Calefacción Orientación  Plantas            Cocina  \
# 0  Parrillero          Hogar       Oeste      1.0   Cocina Definida
# 1         NaN            NaN         NaN      NaN   Cocina Definida
# 2  Parrillero          Hogar         NaN      2.0   Cocina Definida
# 3  Parrillero  losa radiante       Norte      2.0  Cocina Integrada
# 4  Parrillero     Radiadores        Este      2.0   Cocina Definida
#
#    Año de Construcción  Jardín  Acepta Mascotas Superficie Balcones  \
# 0               1923.0  Jardín              NaN                 NaN
# 1               2005.0  Jardín  Acepta Mascotas                 NaN
# 2               1958.0  Jardín              NaN                40m²
# 3               2024.0  Jardín  Acepta Mascotas                20m²
# 4               1979.0  Jardín              NaN                 NaN
#
#    Propiedad Horizontal Seguridad  Piscina Gastos Comúnes Altura  \
# 0                   NaN       NaN      NaN            NaN    NaN
# 1                   NaN       NaN      NaN            NaN    NaN
# 2                   NaN       NaN      NaN            NaN    NaN
# 3  Propiedad Horizontal   virtual      NaN            NaN    NaN
# 4                   NaN       NaN  Piscina            NaN    NaN
#
#    Aptos por piso Disposición Muebles Patio  Pisos Edificio Lavadero  Piso
# 0             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 1             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 2             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 3             NaN         NaN     NaN   NaN             NaN      NaN   NaN
# 4             NaN         NaN     NaN   NaN             NaN      NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1934 entries, 0 to 1933
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    1934 non-null   object
#  1   precio                 1934 non-null   object
#  2   Dormitorios            1934 non-null   object
#  3   Baños                  1862 non-null   float64
#  4   Superficie             1743 non-null   object
#  5   Superficie Construida  1785 non-null   object
#  6   Superficie Terreno     1559 non-null   object
#  7   Dormitorios Servicio   377 non-null    object
#  8   Dormitorios Suite      456 non-null    object
#  9   Garage                 1269 non-null   object
#  10  Parrillero             445 non-null    object
#  11  Calefacción            222 non-null    object
#  12  Orientación            876 non-null    object
#  13  Plantas                572 non-null    float64
#  14  Cocina                 1411 non-null   object
#  15  Año de Construcción    1314 non-null   float64
#  16  Jardín                 841 non-null    object
#  17  Acepta Mascotas        834 non-null    object
#  18  Superficie Balcones    274 non-null    object
#  19  Propiedad Horizontal   201 non-null    object
#  20  Seguridad              126 non-null    object
#  21  Piscina                314 non-null    object
#  22  Gastos Comúnes         150 non-null    object
#  23  Altura                 435 non-null    object
#  24  Aptos por piso         478 non-null    float64
#  25  Disposición            454 non-null    object
#  26  Muebles                43 non-null     object
#  27  Patio                  399 non-null    object
#  28  Pisos Edificio         212 non-null    float64
#  29  Lavadero               332 non-null    object
#  30  Piso                   5 non-null      float64
# dtypes: float64(6), object(25)
# memory usage: 468.5+ KB

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ## Eliminamos duplicados del dataset

# %%
# vemos los duplicados que hay en el dataset 

duplicados = df.duplicated(subset=['url'])
print(f'Duplicados encontrados por URL: {duplicados.sum()}')
# Out:
# Duplicados encontrados por URL: 679

# %%
# dropeamos los duplicados del dataset por url 

df = df.drop_duplicates(subset='url')

# %% [markdown]
# ## DROP DE COLUMNAS -- CRITERIO
#
# Vamos a dropear todas las columnas que tengan menos de 650 datos como criterio inicial. Luego podemos ver de cambiarlo, pero eso será el criterio inicial.

# %%
# Calcular el número de valores no nulos por columna
non_null_counts = df.notnull().sum()

# Define columns that should NEVER be deleted
protected_columns = [
    'Parrillero',
    'Calefacción',
    'Año de Construcción',
    'Jardín',
    'Piscina',
    'Patio'
]

# Identificar las columnas a eliminar (non-null count < 650)
columns_to_drop = non_null_counts[non_null_counts < 650].index

# Exclude protected columns from deletion
columns_to_drop = [col for col in columns_to_drop if col not in protected_columns]

# Eliminar las columnas identificadas
df = df.drop(columns=columns_to_drop)

# Mostrar las columnas restantes
print("Columnas restantes:", df.columns.tolist())
print(f"\nColumnas eliminadas: {len(columns_to_drop)}")
print(f"Columnas protegidas mantenidas: {[col for col in protected_columns if col in df.columns]}")
# Out:
# Columnas restantes: ['url', 'precio', 'Dormitorios', 'Baños', 'Superficie', 'Superficie Construida', 'Superficie Terreno', 'Garage', 'Parrillero', 'Calefacción', 'Cocina', 'Año de Construcción', 'Jardín', 'Piscina', 'Patio']
#
# Columnas eliminadas: 16
# Columnas protegidas mantenidas: ['Parrillero', 'Calefacción', 'Año de Construcción', 'Jardín', 'Piscina', 'Patio']

# %%
print(columns_to_drop)
# Out:
# ['Dormitorios Servicio', 'Dormitorios Suite', 'Orientación', 'Plantas', 'Acepta Mascotas', 'Superficie Balcones', 'Propiedad Horizontal', 'Seguridad', 'Gastos Comúnes', 'Altura', 'Aptos por piso', 'Disposición', 'Muebles', 'Pisos Edificio', 'Lavadero', 'Piso']

# %%
df.head()
# Out:
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 4  https://www.casasymas.com.uy/propiedad/165019-...  U$S 685.000Venta
#
#   Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0           3    2.0     255 m²                  90m²              255m²
# 1           4    3.0     429 m²                 256m²              429m²
# 2           3    3.0     230 m²                 177m²              230m²
# 3           3    3.0     130 m²                 130m²              150m²
# 4           4    5.0     289 m²                 268m²              811m²
#
#        Garage  Parrillero    Calefacción            Cocina  \
# 0  Cochera: 1  Parrillero          Hogar   Cocina Definida
# 1   Garaje: 4         NaN            NaN   Cocina Definida
# 2   Garaje: 1  Parrillero          Hogar   Cocina Definida
# 3  Cochera: 1  Parrillero  losa radiante  Cocina Integrada
# 4  Cochera: 2  Parrillero     Radiadores   Cocina Definida
#
#    Año de Construcción  Jardín  Piscina Patio
# 0               1923.0  Jardín      NaN   NaN
# 1               2005.0  Jardín      NaN   NaN
# 2               1958.0  Jardín      NaN   NaN
# 3               2024.0  Jardín      NaN   NaN
# 4               1979.0  Jardín  Piscina   NaN

# %%
df.columns
# Out:
# Index(['url', 'precio', 'Dormitorios', 'Baños', 'Superficie',
#        'Superficie Construida', 'Superficie Terreno', 'Garage', 'Parrillero',
#        'Calefacción', 'Cocina', 'Año de Construcción', 'Jardín', 'Piscina',
#        'Patio'],
#       dtype='object')

# %%
df = df.drop(columns=['Dormitorios Suite', 'Dormitorios Servicio', 'Orientación', 'Disposición'], errors='ignore')

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'superficie_construida' y 'superficie_terreno'

# Filtrar las filas que tienen NaN en 'superficie_construida' o 'superficie_terreno'
filas_con_nan = df[df[['Superficie Construida', 'Superficie Terreno', 'Superficie']].isnull().any(axis=1)]

# print(filas_con_nan.value_counts())

# Mostrar las filas con NaN
print(filas_con_nan)
# Out:
#                                                     url              precio  \
# 7     https://www.casasymas.com.uy/propiedad/117530-...  U$S 1.500.000Venta
# 10    https://www.casasymas.com.uy/propiedad/186448-...    U$S 695.000Venta
# 17    https://www.casasymas.com.uy/propiedad/169340-...    U$S 280.000Venta
# 19    https://www.casasymas.com.uy/propiedad/90237-c...    U$S 203.400Venta
# 20    https://www.casasymas.com.uy/propiedad/165774-...  U$S 2.900.000Venta
# ...                                                 ...                 ...
# 1879  https://www.casasymas.com.uy/propiedad/194975-...    U$S 205.000Venta
# 1898  https://www.casasymas.com.uy/propiedad/181831-...    U$S 770.000Venta
# 1903  https://www.casasymas.com.uy/propiedad/120273-...     U$S 55.000Venta
# 1907  https://www.casasymas.com.uy/propiedad/151209-...     U$S 85.000Venta
# 1917  https://www.casasymas.com.uy/propiedad/191947-...    U$S 770.000Venta
#
#      Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 7              8    5.0        NaN                 444m²              666m²
# 10             4    4.0        NaN                 249m²              321m²
# 17             3    2.0     148 m²                 148m²                NaN
# 19             2    2.0        NaN                  60m²                NaN
# 20             7    5.0        NaN                2461m²              722m²
# ...          ...    ...        ...                   ...                ...
# 1879           2    1.0        NaN                   NaN                NaN
# 1898           3    5.0     266 m²                   NaN              421m²
# 1903           1    1.0        NaN                   NaN                NaN
# 1907           3    1.0      90 m²                   NaN                NaN
# 1917           4    3.0        NaN                 300m²              704m²
#
#           Garage  Parrillero         Calefacción            Cocina  \
# 7      Garaje: 2  Parrillero  radiadores por gas   Cocina Definida
# 10     Garaje: 2  Parrillero                 NaN  Cocina Integrada
# 17     Garaje: 1         NaN                 NaN               NaN
# 19    Cochera: 0  Parrillero                 NaN               NaN
# 20     Garaje: 6         NaN                 NaN   Cocina Definida
# ...          ...         ...                 ...               ...
# 1879         NaN         NaN                 NaN   Cocina Definida
# 1898  Cochera: 3  Parrillero   Radiadores y losa   Cocina Definida
# 1903         NaN         NaN                 NaN               NaN
# 1907         NaN         NaN                 NaN   Cocina Definida
# 1917   Garaje: 3         NaN                 NaN               NaN
#
#       Año de Construcción  Jardín  Piscina Patio
# 7                  1928.0  Jardín      NaN   NaN
# 10                 1927.0  Jardín  Piscina   NaN
# 17                    1.0     NaN      NaN   NaN
# 19                    NaN  Jardín  Piscina   NaN
# 20                 1891.0     NaN      NaN   NaN
# ...                   ...     ...      ...   ...
# 1879                  NaN     NaN      NaN   NaN
# 1898                  NaN  Jardín  Piscina   NaN
# 1903                  NaN     NaN      NaN   NaN
# 1907               1960.0     NaN      NaN   NaN
# 1917                  NaN     NaN      NaN   NaN
#
# [362 rows x 15 columns]

# %% [markdown]
# ## Registros fuera de criterios
#
# Criterios:
#
# * Dormitorios: no mas de 10
# * Baños: no mas de 5
# * Garage: no mas de 5

# %%
df.head()
# Out:
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 4  https://www.casasymas.com.uy/propiedad/165019-...  U$S 685.000Venta
#
#   Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0           3    2.0     255 m²                  90m²              255m²
# 1           4    3.0     429 m²                 256m²              429m²
# 2           3    3.0     230 m²                 177m²              230m²
# 3           3    3.0     130 m²                 130m²              150m²
# 4           4    5.0     289 m²                 268m²              811m²
#
#        Garage  Parrillero    Calefacción            Cocina  \
# 0  Cochera: 1  Parrillero          Hogar   Cocina Definida
# 1   Garaje: 4         NaN            NaN   Cocina Definida
# 2   Garaje: 1  Parrillero          Hogar   Cocina Definida
# 3  Cochera: 1  Parrillero  losa radiante  Cocina Integrada
# 4  Cochera: 2  Parrillero     Radiadores   Cocina Definida
#
#    Año de Construcción  Jardín  Piscina Patio
# 0               1923.0  Jardín      NaN   NaN
# 1               2005.0  Jardín      NaN   NaN
# 2               1958.0  Jardín      NaN   NaN
# 3               2024.0  Jardín      NaN   NaN
# 4               1979.0  Jardín  Piscina   NaN

# %%
# Convrtir a string para poder manipular
df['Garage'] = df['Garage'].astype(str)

# Reemplazar "Garaje:" y "Cochera:" por nada (dejar solo el número)
df['Garage'] = df['Garage'].str.replace('Garaje:', '', regex=False)
df['Garage'] = df['Garage'].str.replace('Cochera:', '', regex=False)

# Limpiar espacios en blanco
df['Garage'] = df['Garage'].str.strip()

# Reemplazar 'nan' y strings vacíos por '0'
df['Garage'] = df['Garage'].replace(['nan', '', 'None'], '0')

# Convertir a entero
df['Garage'] = df['Garage'].astype(int)

# %%
df.head()
# Out:
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 4  https://www.casasymas.com.uy/propiedad/165019-...  U$S 685.000Venta
#
#   Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0           3    2.0     255 m²                  90m²              255m²
# 1           4    3.0     429 m²                 256m²              429m²
# 2           3    3.0     230 m²                 177m²              230m²
# 3           3    3.0     130 m²                 130m²              150m²
# 4           4    5.0     289 m²                 268m²              811m²
#
#    Garage  Parrillero    Calefacción            Cocina  Año de Construcción  \
# 0       1  Parrillero          Hogar   Cocina Definida               1923.0
# 1       4         NaN            NaN   Cocina Definida               2005.0
# 2       1  Parrillero          Hogar   Cocina Definida               1958.0
# 3       1  Parrillero  losa radiante  Cocina Integrada               2024.0
# 4       2  Parrillero     Radiadores   Cocina Definida               1979.0
#
#    Jardín  Piscina Patio
# 0  Jardín      NaN   NaN
# 1  Jardín      NaN   NaN
# 2  Jardín      NaN   NaN
# 3  Jardín      NaN   NaN
# 4  Jardín  Piscina   NaN

# %%
# Convert columns to numeric, replacing errors with NaN
df['Dormitorios'] = pd.to_numeric(df['Dormitorios'], errors='coerce')

# Now you can filter
filtered_data = df[(df['Dormitorios'] > 10) | (df['Baños'] > 5) | (df['Garage'] > 5)]

print(f"Cantidad de filas a sacar: {len(filtered_data)}")
# Out:
# Cantidad de filas a sacar: 85

# %%
# Identificamos las filas a eliminar (las que tienen valores extremos)
rows_to_drop = df[(df['Dormitorios'] >= 10) | (df['Baños'] >= 5) | (df['Garage'] >= 5)].index

print(f"Filas a eliminar: {len(rows_to_drop)}")

# Eliminamos esas filas
df = df.drop(rows_to_drop)

print(f"Filas restantes: {len(df)}")
df.head(5)
# Out:
# Filas a eliminar: 168
# Filas restantes: 1087
#                                                  url            precio  \
# 0  https://www.casasymas.com.uy/propiedad/169046-...  U$S 248.000Venta
# 1  https://www.casasymas.com.uy/propiedad/183266-...  U$S 850.000Venta
# 2  https://www.casasymas.com.uy/propiedad/190147-...  U$S 298.000Venta
# 3  https://www.casasymas.com.uy/propiedad/940-cas...  U$S 380.000Venta
# 5  https://www.casasymas.com.uy/propiedad/159162-...  U$S 119.000Venta
#
#    Dormitorios  Baños Superficie Superficie Construida Superficie Terreno  \
# 0          3.0    2.0     255 m²                  90m²              255m²
# 1          4.0    3.0     429 m²                 256m²              429m²
# 2          3.0    3.0     230 m²                 177m²              230m²
# 3          3.0    3.0     130 m²                 130m²              150m²
# 5          2.0    1.0     380 m²                  62m²              380m²
#
#    Garage  Parrillero    Calefacción            Cocina  Año de Construcción  \
# 0       1  Parrillero          Hogar   Cocina Definida               1923.0
# 1       4         NaN            NaN   Cocina Definida               2005.0
# 2       1  Parrillero          Hogar   Cocina Definida               1958.0
# 3       1  Parrillero  losa radiante  Cocina Integrada               2024.0
# 5       0         NaN            NaN   Cocina Definida               1960.0
#
#    Jardín Piscina Patio
# 0  Jardín     NaN   NaN
# 1  Jardín     NaN   NaN
# 2  Jardín     NaN   NaN
# 3  Jardín     NaN   NaN
# 5     NaN     NaN   NaN

# %% [markdown]
# ## Limpieza de campos
#
# Algunos campos tienen incoherencias entonces queremos dejarlos lo mas limpio posibles para nuestro analisis.

# %%
# columna "precio" -> eliminamos el "U$S" y "Venta"

df['precio'] = df['precio'].str.replace("U\\$S", "", regex=True)
df['precio'] = df['precio'].str.replace("Venta", "", regex=True)
df['precio'] = df['precio'].str.replace(".", "", regex=False)
df['precio'] = df['precio'].str.strip()
df['precio'] = pd.to_numeric(df['precio'], errors='coerce')

print(df['precio'].head())
# Out:
# 0    248000.0
# 1    850000.0
# 2    298000.0
# 3    380000.0
# 5    119000.0
# Name: precio, dtype: float64

# %%
# columna "dormitorio" -> cambiamos "Monoambiente" por 0. 

df['Dormitorios'] = df['Dormitorios'].replace("Monoambiente", 0)
df['Dormitorio'] = pd.to_numeric(df['Dormitorios'], errors='coerce')

df = df.drop(columns=['Dormitorios'])

# %%
# columna "Superficie Construida" -> sacamos "mÂ²" y "m²", dejando solo el numero 

df['Superficie Construida'] = df['Superficie Construida'].str.replace("mÂ²", "", regex=False)
df['Superficie Construida'] = df['Superficie Construida'].str.replace("m²", "", regex=False)

# eliminar espacios 

df['Superficie Construida'] = df["Superficie Construida"].str.strip()

# convertir a numero 

df['Superficie Construida'] = pd.to_numeric(df['Superficie Construida'], errors='coerce')

# %%
# columna "Superficie Terreno" -> sacamos "mÂ²" y "m²", dejando solo el numero 

df['Superficie Terreno'] = df['Superficie Terreno'].str.replace("mÂ²", "", regex=False)
df['Superficie Terreno'] = df['Superficie Terreno'].str.replace("m²", "", regex=False)

# eliminar espacios 

df['Superficie Terreno'] = df["Superficie Terreno"].str.strip()

# convertir a numero 

df['Superficie Terreno'] = pd.to_numeric(df['Superficie Terreno'], errors='coerce')

# %%
# columna "Superficie Construida" -> sacamos "mÂ²" y "m²", dejando solo el numero 

df['Superficie'] = df['Superficie'].str.replace("mÂ²", "", regex=False)
df['Superficie'] = df['Superficie'].str.replace("m²", "", regex=False)

# eliminar espacios 

df['Superficie'] = df["Superficie"].str.strip()

# convertir a numero 

df['Superficie'] = pd.to_numeric(df['Superficie'], errors='coerce')

# %%
# drop de filas con NaN en precio

df = df[df['precio'].notna()]

# %%
# chequeamos que no quede nada con NaN en precio

df[df['precio'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, precio, Baños, Superficie, Superficie Construida, Superficie Terreno, Garage, Parrillero, Calefacción, Cocina, Año de Construcción, Jardín, Piscina, Patio, Dormitorio]
# Index: []

# %%
# eliminar chacras del dataset 

rows_to_drop = df[df['Superficie Terreno'] > 20000].index

df = df.drop(rows_to_drop)

df.head(10)
# Out:
#                                                   url     precio  Baños  \
# 0   https://www.casasymas.com.uy/propiedad/169046-...   248000.0    2.0
# 1   https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 2   https://www.casasymas.com.uy/propiedad/190147-...   298000.0    3.0
# 3   https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 5   https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 6   https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 8   https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
# 9   https://www.casasymas.com.uy/propiedad/204883-...   380000.0    2.0
# 10  https://www.casasymas.com.uy/propiedad/186448-...   695000.0    4.0
# 11  https://www.casasymas.com.uy/propiedad/186450-...   380000.0    3.0
#
#     Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0        255.0                   90.0               255.0       1  Parrillero
# 1        429.0                  256.0               429.0       4         NaN
# 2        230.0                  177.0               230.0       1  Parrillero
# 3        130.0                  130.0               150.0       1  Parrillero
# 5        380.0                   62.0               380.0       0         NaN
# 6        263.0                  263.0              1316.0       3  Parrillero
# 8        497.0                  195.0               497.0       1         NaN
# 9        250.0                  180.0               250.0       1         NaN
# 10         NaN                  249.0               321.0       2  Parrillero
# 11       130.0                  110.0                20.0       0  Parrillero
#
#                 Calefacción            Cocina  Año de Construcción  Jardín  \
# 0                     Hogar   Cocina Definida               1923.0  Jardín
# 1                       NaN   Cocina Definida               2005.0  Jardín
# 2                     Hogar   Cocina Definida               1958.0  Jardín
# 3             losa radiante  Cocina Integrada               2024.0  Jardín
# 5                       NaN   Cocina Definida               1960.0     NaN
# 6   Losa radiante eléctrica   Cocina Definida               2006.0  Jardín
# 8                       NaN   Cocina Definida               1989.0  Jardín
# 9                       NaN   Cocina Definida               1970.0  Jardín
# 10                      NaN  Cocina Integrada               1927.0  Jardín
# 11                      NaN               NaN                  NaN  Jardín
#
#     Piscina Patio  Dormitorio
# 0       NaN   NaN         3.0
# 1       NaN   NaN         4.0
# 2       NaN   NaN         3.0
# 3       NaN   NaN         3.0
# 5       NaN   NaN         2.0
# 6   Piscina   NaN         3.0
# 8       NaN   NaN         3.0
# 9       NaN   NaN         4.0
# 10  Piscina   NaN         4.0
# 11      NaN   NaN         3.0

# %% [markdown]
# ## AGREGAR BARRIOS

# %%
barrios = {
    "aguada": "B",
    "aires-puros": "C", 
    "atahualpa": "C", 
    "banados-de-carrasco": "F", 
    "barrio-sur": "B", 
    "belvedere": "A",
    "brazo-oriental": "C", 
    "buceo": "CH", 
    "bella-vista": "C", 
    "capurro": "C", 
    "carrasco": "E", 
    "carrasco-norte": "E", 
    "casabo": "A", 
    "pajas-blancas": "A", 
    "casavalle": "D", 
    "castro": "D", 
    "perez-castellanos": "D", 
    "centro": "B", 
    "cerrito": "D",
    "cerro": "A", 
    "ciudad-vieja": "B", 
    "colon": "G", 
    "conciliacion": "G", 
    "cordon": "B", 
    "abayuba": "G", 
    "flor-de-maronas": "F", 
    "ituzaingo": "F", 
    "jacinto-vera": "C", 
    "jardines-del-hipodromo": "F", 
    "la-paloma": "A", 
    "la-teja": "A", 
    "larranaga": "C", 
    "las-acacias": "D", 
    "las-canteras": "E", 
    "lezica": "G", 
    "melilla": "G", 
    "malvin": "E", 
    "malvin-norte": "E", 
    "paso-de-las-duranas": "G",
    "manga": "F", 
    "toledo-chico": "D", 
    "maronas": "F", 
    "parque-guarani": "F",
    "mercado-modelo": "C", 
    "bolivar": "C", 
    "nuevo-paris": "A", 
    "palermo": "B", 
    "parque-batlle": "CH", 
    "villa-dolores": "CH", 
    "parque-rodo": "B", 
    "paso-de-la-arena": "A", 
    "penarol": "G", 
    "lavalleja": "G", 
    "piedras-blancas": "D",
    "pocitos": "CH", 
    "prado": "A", 
    "nueva-savona": "A", 
    "punta-carretas": "CH", 
    "punta-gorda": "E", 
    "punta-rieles": "F", 
    "bella-italia": "F", 
    "reducto": "C", 
    "sayago": "G", 
    "tres-cruces": "B",  
    "tres-ombues": "A", 
    "victoria": "A",
    "union": "D", 
    "villa-espanola": "D", 
    "villa-garcia": "F", 
    "villa-munoz": "C", 
    "paso-molino": "A", 
    "la-comercial": "B",
    "san-nicolas": "E", 
    "goes": "C", 
    "parque-rivera": "E", 
    "la-blanqueada": "CH", 
    "la-figurita": "C"
}

barrios_sorted = sorted(barrios, key=len, reverse = True)

def extraer_barrios_de_url(url: str) -> str | None:
    for barrio in barrios_sorted:
        if barrio in url: 
            return barrio
    return None

df["barrio"] = df["url"].apply(extraer_barrios_de_url)
df["municipio"] = df["barrio"].map(barrios)

# %%
# Cuenta la cantidad de nulos en la columna barrio
num_nulos = df["barrio"].isna().sum()

print("Cantidad de nulos en 'barrio':", num_nulos)
# Out:
# Cantidad de nulos en 'barrio': 100

# %%
df = df.dropna(subset=["barrio"]).reset_index(drop=True)

# %%
# Cuenta la cantidad de nulos en la columna barrio
num_nulos = df["barrio"].isna().sum()

print("Cantidad de nulos en 'barrio':", num_nulos)
# Out:
# Cantidad de nulos en 'barrio': 0

# %% [markdown]
# ## AGREGAR COLUMNA BARRIO

# %%
barrios = df['url']

print(barrios)
# Out:
# 0      https://www.casasymas.com.uy/propiedad/183266-...
# 1      https://www.casasymas.com.uy/propiedad/940-cas...
# 2      https://www.casasymas.com.uy/propiedad/159162-...
# 3      https://www.casasymas.com.uy/propiedad/133140-...
# 4      https://www.casasymas.com.uy/propiedad/205399-...
#                              ...
# 974    https://www.casasymas.com.uy/propiedad/170075-...
# 975    https://www.casasymas.com.uy/propiedad/191947-...
# 976    https://www.casasymas.com.uy/propiedad/103224-...
# 977    https://www.casasymas.com.uy/propiedad/202384-...
# 978    https://www.casasymas.com.uy/propiedad/190421-...
# Name: url, Length: 979, dtype: object

# %% [markdown]
# ## ONE HOT ENCODING + TRANSFORMACIONES EN AñO DE CONSTRUCCIÓN

# %%
df.head()
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4         NaN
# 1       130.0                  130.0               150.0       1  Parrillero
# 2       380.0                   62.0               380.0       0         NaN
# 3       263.0                  263.0              1316.0       3  Parrillero
# 4       497.0                  195.0               497.0       1         NaN
#
#                Calefacción            Cocina  Año de Construcción  Jardín  \
# 0                      NaN   Cocina Definida               2005.0  Jardín
# 1            losa radiante  Cocina Integrada               2024.0  Jardín
# 2                      NaN   Cocina Definida               1960.0     NaN
# 3  Losa radiante eléctrica   Cocina Definida               2006.0  Jardín
# 4                      NaN   Cocina Definida               1989.0  Jardín
#
#    Piscina Patio  Dormitorio       barrio municipio
# 0      NaN   NaN         4.0     carrasco         E
# 1      NaN   NaN         3.0     carrasco         E
# 2      NaN   NaN         2.0  tres-cruces         B
# 3  Piscina   NaN         3.0  san-nicolas         E
# 4      NaN   NaN         3.0        buceo        CH

# %%
# Convert columns to binary: 0 if empty/null, 1 if has any value
columns_to_binarize = ['Parrillero', 'Calefacción', 'Jardín', 'Piscina', 'Patio']

for col in columns_to_binarize:
    if col in df.columns:
        # Convert to 1 if not null/empty, 0 otherwise
        df[col] = df[col].notna().astype(int)
        print(f"✅ {col}: {df[col].sum()} propiedades tienen esta característica")
    else:
        print(f"⚠️ Columna '{col}' no encontrada en el dataset")

# Show the distribution
print("\nDistribución de características:")
for col in columns_to_binarize:
    if col in df.columns:
        print(f"{col}:")
        print(f"  Sí (1): {df[col].sum()}")
        print(f"  No (0): {(df[col] == 0).sum()}")
# Out:
# ✅ Parrillero: 206 propiedades tienen esta característica
# ✅ Calefacción: 94 propiedades tienen esta característica
# ✅ Jardín: 380 propiedades tienen esta característica
# ✅ Piscina: 127 propiedades tienen esta característica
# ✅ Patio: 198 propiedades tienen esta característica
#
# Distribución de características:
# Parrillero:
#   Sí (1): 206
#   No (0): 773
# Calefacción:
#   Sí (1): 94
#   No (0): 885
# Jardín:
#   Sí (1): 380
#   No (0): 599
# Piscina:
#   Sí (1): 127
#   No (0): 852
# Patio:
#   Sí (1): 198
#   No (0): 781

# %%
df.head()
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4           0
# 1       130.0                  130.0               150.0       1           1
# 2       380.0                   62.0               380.0       0           0
# 3       263.0                  263.0              1316.0       3           1
# 4       497.0                  195.0               497.0       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida               2005.0       1        0      0
# 1            1  Cocina Integrada               2024.0       1        0      0
# 2            0   Cocina Definida               1960.0       0        0      0
# 3            1   Cocina Definida               2006.0       1        1      0
# 4            0   Cocina Definida               1989.0       1        0      0
#
#    Dormitorio       barrio municipio
# 0         4.0     carrasco         E
# 1         3.0     carrasco         E
# 2         2.0  tres-cruces         B
# 3         3.0  san-nicolas         E
# 4         3.0        buceo        CH

# %%
import pandas as pd
import numpy as np

# Convert to numeric, coercing errors to NaN
df['Año de Construcción'] = pd.to_numeric(df['Año de Construcción'], errors='coerce')

# If year is less than 1800, add 1900
df.loc[df['Año de Construcción'] < 1800, 'Año de Construcción'] += 1900

# %%
df.head()
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4           0
# 1       130.0                  130.0               150.0       1           1
# 2       380.0                   62.0               380.0       0           0
# 3       263.0                  263.0              1316.0       3           1
# 4       497.0                  195.0               497.0       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida               2005.0       1        0      0
# 1            1  Cocina Integrada               2024.0       1        0      0
# 2            0   Cocina Definida               1960.0       0        0      0
# 3            1   Cocina Definida               2006.0       1        1      0
# 4            0   Cocina Definida               1989.0       1        0      0
#
#    Dormitorio       barrio municipio
# 0         4.0     carrasco         E
# 1         3.0     carrasco         E
# 2         2.0  tres-cruces         B
# 3         3.0  san-nicolas         E
# 4         3.0        buceo        CH

# %%
import pandas as pd
import numpy as np

# Convert to numeric, coercing errors to NaN
df['Año de Construcción'] = pd.to_numeric(df['Año de Construcción'], errors='coerce')

# If year is less than 1800, add 1900
df.loc[df['Año de Construcción'] < 1800, 'Año de Construcción'] += 1900

# Show results
# print("✅ Años menores a 1800 corregidos (sumando 1900)")
# print(f"\nValores únicos (muestra):")
# print(df['Año de Construcción'].value_counts().head(20))
# print(f"\nRango de años: {df['Año de Construcción'].min()} - {df['Año de Construcción'].max()}")
# print(f"Valores nulos: {df['Año de Construcción'].isna().sum()}")

# Calculate average construction year per neighborhood and store in dict (without modifying df)
avg_year_by_barrio = df.groupby('barrio')['Año de Construcción'].mean().to_dict()

print(avg_year_by_barrio)
# Out:
# {'aguada': 1941.0, 'aires-puros': 1979.0, 'atahualpa': 1947.5, 'barrio-sur': 1942.0, 'bella-vista': 1957.0, 'belvedere': 1967.7142857142858, 'bolivar': 1972.5, 'brazo-oriental': 1955.357142857143, 'buceo': 1960.625, 'capurro': 1948.3333333333333, 'carrasco': 1977.981981981982, 'carrasco-norte': 1984.5471698113208, 'centro': 1941.5, 'cerrito': 2000.0, 'cerro': 1940.75, 'ciudad-vieja': 1944.75, 'colon': 1960.4545454545455, 'conciliacion': 1961.6666666666667, 'cordon': 1942.6, 'flor-de-maronas': 1947.6, 'goes': 1936.0, 'ituzaingo': nan, 'jacinto-vera': 1956.625, 'jardines-del-hipodromo': 1949.0, 'la-blanqueada': 1957.7777777777778, 'la-comercial': 1930.4444444444443, 'la-figurita': 1947.5, 'la-teja': 1962.3333333333333, 'larranaga': 1957.0, 'las-acacias': 1998.0, 'lezica': 1972.857142857143, 'malvin': 1966.2727272727273, 'malvin-norte': 1972.1818181818182, 'manga': 1950.0, 'maronas': 1963.0, 'mercado-modelo': nan, 'nuevo-paris': 1945.0, 'pajas-blancas': 1945.5, 'palermo': 1950.5, 'parque-batlle': 1943.111111111111, 'parque-rivera': nan, 'parque-rodo': 1956.2, 'paso-de-la-arena': 1974.5, 'paso-molino': 1944.9, 'penarol': 1944.0, 'perez-castellanos': 1933.0, 'piedras-blancas': 1953.5, 'pocitos': 1942.2708333333333, 'prado': 1956.0384615384614, 'punta-carretas': 1940.9411764705883, 'punta-gorda': 1962.4375, 'punta-rieles': 1956.0, 'reducto': 1949.4444444444443, 'san-nicolas': 2009.0714285714287, 'sayago': 1955.7777777777778, 'tres-cruces': 1949.25, 'tres-ombues': 1960.0, 'union': 1959.2307692307693, 'victoria': 1928.0, 'villa-dolores': 1924.0, 'villa-espanola': 1952.0, 'villa-garcia': 1965.0, 'villa-munoz': 1939.5}

# %%
df.head()
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4           0
# 1       130.0                  130.0               150.0       1           1
# 2       380.0                   62.0               380.0       0           0
# 3       263.0                  263.0              1316.0       3           1
# 4       497.0                  195.0               497.0       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida               2005.0       1        0      0
# 1            1  Cocina Integrada               2024.0       1        0      0
# 2            0   Cocina Definida               1960.0       0        0      0
# 3            1   Cocina Definida               2006.0       1        1      0
# 4            0   Cocina Definida               1989.0       1        0      0
#
#    Dormitorio       barrio municipio
# 0         4.0     carrasco         E
# 1         3.0     carrasco         E
# 2         2.0  tres-cruces         B
# 3         3.0  san-nicolas         E
# 4         3.0        buceo        CH

# %%
# Function to fill missing or 1901 values with neighborhood average
def fill_year_with_barrio_avg(row):
    year = row['Año de Construcción']
    barrio = row['barrio']
    
    # If year is NaN or 1901, replace with barrio average
    if pd.isna(year) or year == 1901:
        if barrio in avg_year_by_barrio and not pd.isna(avg_year_by_barrio[barrio]):
            return avg_year_by_barrio[barrio]
        else:
            # If barrio doesn't have an average, use global average
            return df['Año de Construcción'].mean()
    
    return year

# Count values before filling
na_count_before = df['Año de Construcción'].isna().sum()
count_1901_before = (df['Año de Construcción'] == 1901).sum()

print(f"Valores a rellenar:")
print(f"  NaN: {na_count_before}")
print(f"  1901: {count_1901_before}")
print(f"  Total: {na_count_before + count_1901_before}")

# Apply the function
df['Año de Construcción'] = df.apply(fill_year_with_barrio_avg, axis=1)

# Count after filling
na_count_after = df['Año de Construcción'].isna().sum()
count_1901_after = (df['Año de Construcción'] == 1901).sum()

print(f"\n✅ Valores rellenados con promedio del barrio")
print(f"  NaN restantes: {na_count_after}")
print(f"  1901 restantes: {count_1901_after}")

# Convert to integer
df['Año de Construcción'] = df['Año de Construcción'].round().astype(int)
# Out:
# Valores a rellenar:
#   NaN: 342
#   1901: 99
#   Total: 441
#
# ✅ Valores rellenados con promedio del barrio
#   NaN restantes: 0
#   1901 restantes: 0

# %%
df.head()
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4           0
# 1       130.0                  130.0               150.0       1           1
# 2       380.0                   62.0               380.0       0           0
# 3       263.0                  263.0              1316.0       3           1
# 4       497.0                  195.0               497.0       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida                 2005       1        0      0
# 1            1  Cocina Integrada                 2024       1        0      0
# 2            0   Cocina Definida                 1960       0        0      0
# 3            1   Cocina Definida                 2006       1        1      0
# 4            0   Cocina Definida                 1989       1        0      0
#
#    Dormitorio       barrio municipio
# 0         4.0     carrasco         E
# 1         3.0     carrasco         E
# 2         2.0  tres-cruces         B
# 3         3.0  san-nicolas         E
# 4         3.0        buceo        CH

# %% [markdown]
# # COMIENZA EDA

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#              precio       Baños   Superficie  Superficie Construida  \
# count  9.790000e+02  944.000000   886.000000             902.000000
# mean   3.856933e+05    2.260593   298.558916             173.993348
# std    3.244899e+05    0.985523   324.042604             109.832968
# min    3.350000e+02    1.000000    10.000000              16.000000
# 25%    1.695000e+05    1.000000   123.250000             100.000000
# 50%    2.900000e+05    2.000000   204.500000             145.000000
# 75%    4.600000e+05    3.000000   356.750000             214.000000
# max    2.250000e+06    4.000000  6000.000000             766.000000
#
#        Superficie Terreno      Garage  Parrillero  Calefacción  \
# count          772.000000  979.000000  979.000000   979.000000
# mean           386.474093    0.962206    0.210419     0.096016
# std            693.037342    1.025045    0.407814     0.294764
# min              6.000000    0.000000    0.000000     0.000000
# 25%            120.000000    0.000000    0.000000     0.000000
# 50%            240.000000    1.000000    0.000000     0.000000
# 75%            480.000000    2.000000    0.000000     0.000000
# max           8886.000000    4.000000    1.000000     1.000000
#
#        Año de Construcción      Jardín     Piscina       Patio  Dormitorio
# count           979.000000  979.000000  979.000000  979.000000  963.000000
# mean           1966.503575    0.388151    0.129724    0.202247    3.288681
# std              26.763463    0.487578    0.336171    0.401881    1.135217
# min            1900.000000    0.000000    0.000000    0.000000    1.000000
# 25%            1946.000000    0.000000    0.000000    0.000000    3.000000
# 50%            1961.000000    0.000000    0.000000    0.000000    3.000000
# 75%            1978.000000    1.000000    0.000000    0.000000    4.000000
# max            2025.000000    1.000000    1.000000    1.000000    9.000000

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calcula la matriz de correlación usando solo las columnas numéricas
correlation_matrix = numeric_df.corr()

# Crea un mapa de calor para visualizar la matriz de correlación
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

# Muestra el gráfico
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# ## Boxplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Columnas a graficar
columnas_interes = ['precio', 'Baños', 'Superficie Construida',
                    'Superficie Terreno', 'Dormitorio']

# Crear figura con 3 filas y 2 columnas
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# Aplanar los ejes para iterar más fácil
axes = axes.flatten()

# Crear cada boxplot de forma individual
for ax, col in zip(axes, columnas_interes):
    sns.boxplot(y=df[col], ax=ax, color="skyblue")
    ax.set_title(f'Boxplot de {col}')
    ax.set_xlabel("")  # quitar etiqueta del eje X
    ax.set_ylabel(col)

# Ajustar espacios
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Calcular mediana del precio por municipio
orden_municipios = (df.groupby("municipio")["precio"].median().sort_values(ascending=False).index)

# Crear boxplot ordenado por mediana
plt.figure(figsize=(12, 6))
sns.boxplot(
    x="precio",
    y="municipio",
    data=df,
    order=orden_municipios
)

plt.title("Distribución de Precios por Municipio (ordenado por mediana)")
plt.xlabel("Precio")
plt.ylabel("Municipio")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cantidad de datos por municipio

# %%
# Asegúrate de que 'df' es tu DataFrame y 'municipio' es la columna que contiene los municipios
cantidad_por_municipio = df['municipio'].value_counts()

# Mostrar la cantidad de datos por municipio
print(cantidad_por_municipio)
# Out:
# municipio
# E     359
# CH    201
# B     121
# A      98
# C      92
# G      48
# D      37
# F      23
# Name: count, dtype: int64

# %% [markdown]
# ## Precio m2
#
# basado en superficie contruida y en superficie terreno.

# %%
df.head(5)
# Out:
#                                                  url     precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...   850000.0    3.0
# 1  https://www.casasymas.com.uy/propiedad/940-cas...   380000.0    3.0
# 2  https://www.casasymas.com.uy/propiedad/159162-...   119000.0    1.0
# 3  https://www.casasymas.com.uy/propiedad/133140-...  1780000.0    4.0
# 4  https://www.casasymas.com.uy/propiedad/205399-...   370000.0    3.0
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0       429.0                  256.0               429.0       4           0
# 1       130.0                  130.0               150.0       1           1
# 2       380.0                   62.0               380.0       0           0
# 3       263.0                  263.0              1316.0       3           1
# 4       497.0                  195.0               497.0       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida                 2005       1        0      0
# 1            1  Cocina Integrada                 2024       1        0      0
# 2            0   Cocina Definida                 1960       0        0      0
# 3            1   Cocina Definida                 2006       1        1      0
# 4            0   Cocina Definida                 1989       1        0      0
#
#    Dormitorio       barrio municipio
# 0         4.0     carrasco         E
# 1         3.0     carrasco         E
# 2         2.0  tres-cruces         B
# 3         3.0  san-nicolas         E
# 4         3.0        buceo        CH

# %%
# Asegúrate de que 'df' tiene las columnas 'precio', 'superficie_construida' y 'superficie_terreno'

# Calcular el precio por metro cuadrado basado en la superficie construida
df['precio_por_m2_construido'] = df['precio'] / df['Superficie Construida']

# Calcular el precio por metro cuadrado basado en la superficie del terreno
df['precio_por_m2_terreno'] = df['precio'] / df['Superficie Terreno']

df['precio_por_m2'] = df['precio'] / df['Superficie']

# Mostrar las nuevas columnas
print(df[['precio', 'Superficie Construida', 'precio_por_m2_construido', 'Superficie Terreno', 'precio_por_m2_terreno']])
# Out:
#         precio  Superficie Construida  precio_por_m2_construido  \
# 0     850000.0                  256.0               3320.312500
# 1     380000.0                  130.0               2923.076923
# 2     119000.0                   62.0               1919.354839
# 3    1780000.0                  263.0               6768.060837
# 4     370000.0                  195.0               1897.435897
# ..         ...                    ...                       ...
# 974   320000.0                  100.0               3200.000000
# 975   770000.0                  300.0               2566.666667
# 976    95000.0                   70.0               1357.142857
# 977   259000.0                   76.0               3407.894737
# 978   160000.0                  146.0               1095.890411
#
#      Superficie Terreno  precio_por_m2_terreno
# 0                 429.0            1981.351981
# 1                 150.0            2533.333333
# 2                 380.0             313.157895
# 3                1316.0            1352.583587
# 4                 497.0             744.466801
# ..                  ...                    ...
# 974               547.0             585.009141
# 975               704.0            1093.750000
# 976               100.0             950.000000
# 977               125.0            2072.000000
# 978               554.0             288.808664
#
# [979 rows x 5 columns]

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'superficie_construida' y 'superficie_terreno'

# Filtrar las filas que tienen NaN en 'superficie_construida' o 'superficie_terreno'
filas_con_nan = df[df[['Superficie Construida', 'Superficie Terreno']].isnull().any(axis=1)]

# Mostrar las filas con NaN
print(filas_con_nan)
# Out:
#                                                    url    precio  Baños  \
# 11   https://www.casasymas.com.uy/propiedad/169340-...  280000.0    2.0
# 13   https://www.casasymas.com.uy/propiedad/90237-c...  203400.0    2.0
# 28   https://www.casasymas.com.uy/propiedad/200968-...  695000.0    3.0
# 30   https://www.casasymas.com.uy/propiedad/194470-...  267000.0    3.0
# 31   https://www.casasymas.com.uy/propiedad/206369-...  128000.0    2.0
# ..                                                 ...       ...    ...
# 959  https://www.casasymas.com.uy/propiedad/137357-...  388000.0    1.0
# 961  https://www.casasymas.com.uy/propiedad/34846-c...  780000.0    3.0
# 962  https://www.casasymas.com.uy/propiedad/194975-...  205000.0    1.0
# 970  https://www.casasymas.com.uy/propiedad/120273-...   55000.0    1.0
# 972  https://www.casasymas.com.uy/propiedad/151209-...   85000.0    1.0
#
#      Superficie  Superficie Construida  Superficie Terreno  Garage  \
# 11        148.0                  148.0                 NaN       1
# 13          NaN                   60.0                 NaN       0
# 28        210.0                  210.0                 NaN       2
# 30        301.0                  174.0                 NaN       1
# 31        105.0                  105.0                 NaN       0
# ..          ...                    ...                 ...     ...
# 959       120.0                   16.0                 NaN       2
# 961       900.0                  364.0                 NaN       3
# 962         NaN                    NaN                 NaN       0
# 970         NaN                    NaN                 NaN       0
# 972        90.0                    NaN                 NaN       0
#
#      Parrillero  Calefacción           Cocina  Año de Construcción  Jardín  \
# 11            0            0              NaN                 1956       0
# 13            1            0              NaN                 1978       1
# 28            0            0  Cocina Definida                 2025       1
# 30            0            0  Cocina Definida                 1942       0
# 31            0            0  Cocina Definida                 2025       0
# ..          ...          ...              ...                  ...     ...
# 959           0            0              NaN                 1956       0
# 961           1            1  Cocina Definida                 1978       1
# 962           0            0  Cocina Definida                 1968       0
# 970           0            0              NaN                 1928       0
# 972           0            0  Cocina Definida                 1960       0
#
#      Piscina  Patio  Dormitorio       barrio municipio  \
# 11         0      0         3.0  parque-rodo         B
# 13         1      0         2.0     carrasco         E
# 28         1      0         4.0     carrasco         E
# 30         0      0         5.0       centro         B
# 31         0      0         3.0      palermo         B
# ..       ...    ...         ...          ...       ...
# 959        0      0         3.0        prado         A
# 961        0      0         5.0     carrasco         E
# 962        0      0         2.0    belvedere         A
# 970        0      0         1.0     victoria         A
# 972        0      0         3.0      la-teja         A
#
#      precio_por_m2_construido  precio_por_m2_terreno  precio_por_m2
# 11                1891.891892                    NaN    1891.891892
# 13                3390.000000                    NaN            NaN
# 28                3309.523810                    NaN    3309.523810
# 30                1534.482759                    NaN     887.043189
# 31                1219.047619                    NaN    1219.047619
# ..                        ...                    ...            ...
# 959              24250.000000                    NaN    3233.333333
# 961               2142.857143                    NaN     866.666667
# 962                       NaN                    NaN            NaN
# 970                       NaN                    NaN            NaN
# 972                       NaN                    NaN     944.444444
#
# [235 rows x 20 columns]

# %% [markdown]
# ## Precio promedio por municipio

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio'

# Calcular el precio promedio por municipio
precio_promedio_por_municipio = df.groupby('municipio')['precio'].mean()

# Calcular la cantidad de propiedades por municipio
cantidad_propiedades_por_municipio = df.groupby('municipio').size()

# Combinar ambos resultados en un DataFrame
resultado_municipio = pd.DataFrame({
    'precio_promedio': precio_promedio_por_municipio,
    'cantidad_propiedades': cantidad_propiedades_por_municipio
})

# Ordenar de mayor a menor por precio promedio
resultado_municipio = resultado_municipio.sort_values(by='precio_promedio', ascending=False)

# Mostrar el resultado
print(resultado_municipio)
# Out:
#            precio_promedio  cantidad_propiedades
# municipio
# E            607027.139276                   359
# CH           389487.562189                   201
# B            217078.801653                   121
# C            210500.000000                    92
# A            210188.765306                    98
# D            145056.756757                    37
# G            141458.333333                    48
# F            130256.739130                    23

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio_por_m2_construido'

# Calcular el precio promedio por m2 construido por municipio
precio_promedio_por_m2_construido = df.groupby('municipio')['precio_por_m2_construido'].mean()

# Calcular la cantidad de propiedades por municipio
cantidad_propiedades_por_municipio = df.groupby('municipio').size()

# Combinar ambos resultados en un DataFrame
resultado_m2_municipio = pd.DataFrame({
    'precio_promedio_por_m2': precio_promedio_por_m2_construido,
    'cantidad_propiedades': cantidad_propiedades_por_municipio
})

# Ordenar de mayor a menor por precio promedio por m2
resultado_m2_municipio = resultado_m2_municipio.sort_values(by='precio_promedio_por_m2', ascending=False)

# Mostrar el resultado
print(resultado_m2_municipio)
# Out:
#            precio_promedio_por_m2  cantidad_propiedades
# municipio
# E                     3181.554159                   359
# A                     2933.380078                    98
# CH                    2409.905183                   201
# C                     1541.037199                    92
# B                     1446.641710                   121
# D                     1344.464342                    37
# F                     1187.961204                    23
# G                     1178.334683                    48

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio_por_m2_terreno'

# Calcular el precio promedio por m2 terreno por municipio
precio_promedio_por_m2_terreno = df.groupby('municipio')['precio_por_m2_terreno'].mean()

# Calcular la cantidad de propiedades por municipio
cantidad_propiedades_por_municipio = df.groupby('municipio').size()

# Combinar ambos resultados en un DataFrame
resultado_m2_terreno_municipio = pd.DataFrame({
    'precio_promedio_por_m2_terreno': precio_promedio_por_m2_terreno,
    'cantidad_propiedades': cantidad_propiedades_por_municipio
})

# Ordenar de mayor a menor por precio promedio por m2 terreno
resultado_m2_terreno_municipio = resultado_m2_terreno_municipio.sort_values(by='precio_promedio_por_m2_terreno', ascending=False)

# Mostrar el resultado
print(resultado_m2_terreno_municipio)
# Out:
#            precio_promedio_por_m2_terreno  cantidad_propiedades
# municipio
# CH                            4240.337224                   201
# C                             2561.080716                    92
# E                             2418.146932                   359
# B                             2348.119593                   121
# A                             1749.573725                    98
# D                              723.975745                    37
# G                              457.053801                    48
# F                              318.194977                    23

# %% [markdown]
# ## Lo mismo por barrios

# %%
# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'barrio' y 'precio'

# Calcular el precio promedio por barrio
precio_promedio_por_barrios = df.groupby('barrio')['precio'].mean()

# Calcular la cantidad de propiedades por barrio
cantidad_propiedades_por_barrio = df.groupby('barrio').size()

# Combinar ambos resultados en un DataFrame
resultado = pd.DataFrame({
    'precio_promedio': precio_promedio_por_barrios,
    'cantidad_propiedades': cantidad_propiedades_por_barrio
})

# Ordenar de mayor a menor por precio promedio
resultado = resultado.sort_values(by='precio_promedio', ascending=False)

# Mostrar el resultado sin decimales
print(resultado.round(0).astype(int))
# Out:
#                  precio_promedio  cantidad_propiedades
# barrio
# san-nicolas              1184556                    18
# carrasco                  723521                   161
# punta-gorda               606041                    49
# punta-carretas            602125                    24
# villa-dolores             465000                     2
# ...                          ...                   ...
# conciliacion               84917                     6
# flor-de-maronas            78781                     5
# las-acacias                73000                     1
# nuevo-paris                69333                     3
# tres-ombues                49000                     1
#
# [63 rows x 2 columns]

# %%
# Configurar pandas para mostrar números sin decimales
pd.set_option('display.float_format', '{:.0f}'.format)

# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'barrio' y 'precio_por_m2_construido'

# Calcular el precio promedio por m2 construido por barrio
precio_promedio_por_m2_construido_barrios = df.groupby('barrio')['precio_por_m2_construido'].mean()

precio_promedio_por_m2_construido_barrios = precio_promedio_por_m2_construido_barrios.sort_values(ascending=False)

# Mostrar el precio promedio por barrio
print(precio_promedio_por_m2_construido_barrios)
# Out:
# barrio
# san-nicolas      5410
# prado            4527
# carrasco         3425
# carrasco-norte   3156
# villa-dolores    2951
#                  ...
# ituzaingo         757
# nuevo-paris       646
# ciudad-vieja      586
# villa-garcia      410
# tres-ombues       NaN
# Name: precio_por_m2_construido, Length: 63, dtype: float64

# %%
# Configurar pandas para mostrar números sin decimales
pd.set_option('display.float_format', '{:.0f}'.format)

# Calcular el precio promedio por metro cuadrado de terreno por barrio
precio_promedio_por_m2_terreno_barrios = df.groupby('barrio')['precio_por_m2_terreno'].mean()

# Ordenar de mayor a menor
precio_promedio_por_m2_terreno_barrios = precio_promedio_por_m2_terreno_barrios.sort_values(ascending=False)

# Mostrar el precio promedio por metro cuadrado de terreno por barrio
print(precio_promedio_por_m2_terreno_barrios)
# Out:
# barrio
# parque-batlle            9967
# brazo-oriental           5470
# tres-ombues              4900
# punta-carretas           4552
# pocitos                  4514
#                          ...
# villa-garcia              219
# pajas-blancas             205
# jardines-del-hipodromo    157
# punta-rieles              124
# las-acacias               NaN
# Name: precio_por_m2_terreno, Length: 63, dtype: float64

# %% [markdown]
# ## Precio promedio por m2 construido, m2 terreno

# %%
df.head()
# Out:
#                                                  url  precio  Baños  \
# 0  https://www.casasymas.com.uy/propiedad/183266-...  850000      3
# 1  https://www.casasymas.com.uy/propiedad/940-cas...  380000      3
# 2  https://www.casasymas.com.uy/propiedad/159162-...  119000      1
# 3  https://www.casasymas.com.uy/propiedad/133140-... 1780000      4
# 4  https://www.casasymas.com.uy/propiedad/205399-...  370000      3
#
#    Superficie  Superficie Construida  Superficie Terreno  Garage  Parrillero  \
# 0         429                    256                 429       4           0
# 1         130                    130                 150       1           1
# 2         380                     62                 380       0           0
# 3         263                    263                1316       3           1
# 4         497                    195                 497       1           0
#
#    Calefacción            Cocina  Año de Construcción  Jardín  Piscina  Patio  \
# 0            0   Cocina Definida                 2005       1        0      0
# 1            1  Cocina Integrada                 2024       1        0      0
# 2            0   Cocina Definida                 1960       0        0      0
# 3            1   Cocina Definida                 2006       1        1      0
# 4            0   Cocina Definida                 1989       1        0      0
#
#    Dormitorio       barrio municipio  precio_por_m2_construido  \
# 0           4     carrasco         E                      3320
# 1           3     carrasco         E                      2923
# 2           2  tres-cruces         B                      1919
# 3           3  san-nicolas         E                      6768
# 4           3        buceo        CH                      1897
#
#    precio_por_m2_terreno  precio_por_m2
# 0                   1981           1981
# 1                   2533           2923
# 2                    313            313
# 3                   1353           6768
# 4                    744            744

# %%
# Configurar pandas para mostrar todos los datos sin cortar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.0f}'.format)

# Crear la tabla directamente con groupby y agg
tabla_completa = df.groupby('barrio').agg({
    'precio_por_m2': 'mean',
    'precio_por_m2_construido': 'mean',
    'precio_por_m2_terreno': 'mean',
    'url': 'count' 
}).rename(columns={'url': 'cantidad_propiedades'})

# Ordenar de mayor a menor por precio promedio
tabla_completa = tabla_completa.sort_values(by='precio_por_m2_construido', ascending=False)

# También puedes guardar en una variable para manipular después
df_tabla_barrios = tabla_completa.copy()

df_tabla_barrios.head(20)
# Out:
#                 precio_por_m2  precio_por_m2_construido  \
# barrio
# san-nicolas              2437                      5410
# prado                    1707                      4527
# carrasco                 2599                      3425
# carrasco-norte           2398                      3156
# villa-dolores            2222                      2951
# punta-carretas           2464                      2741
# punta-gorda              3289                      2647
# parque-batlle            1979                      2546
# pocitos                  2140                      2543
# buceo                    1917                      2411
# malvin                   3270                      2353
# parque-rivera             656                      2132
# barrio-sur               1729                      1976
# la-blanqueada            1674                      1947
# atahualpa                1667                      1936
# parque-rodo              1773                      1835
# brazo-oriental           1419                      1770
# tres-cruces              1459                      1659
# malvin-norte              812                      1643
# capurro                   751                      1629
#
#                 precio_por_m2_terreno  cantidad_propiedades
# barrio
# san-nicolas                      1957                    18
# prado                            2729                    49
# carrasco                         2218                   161
# carrasco-norte                   2716                    74
# villa-dolores                    1181                     2
# punta-carretas                   4552                    24
# punta-gorda                      2984                    49
# parque-batlle                    9967                    26
# pocitos                          4514                    65
# buceo                            2657                    38
# malvin                           2793                    38
# parque-rivera                     948                     1
# barrio-sur                       1664                     3
# la-blanqueada                    1501                    46
# atahualpa                        3104                     8
# parque-rodo                      3942                    12
# brazo-oriental                   5470                    24
# tres-cruces                      2165                    18
# malvin-norte                      813                    18
# capurro                          1262                     3

# %% [markdown]
# ## Boxplots

# %%
# Configurar pandas para mostrar números en formato decimal
pd.set_option('display.float_format', '{:.0f}'.format)

# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio_por_m2_construido'

# Calcular la mediana por municipio para ordenar
mediana_por_municipio = df.groupby('municipio')['precio_por_m2_construido'].median().sort_values(ascending=False)

# Obtener el orden de los municipios (de mayor a menor mediana)
orden_municipios = mediana_por_municipio.index.tolist()

# Crear el boxplot con municipios ordenados en el eje Y por mediana
plt.figure(figsize=(12, 8))
sns.boxplot(y='municipio', x='precio_por_m2_construido', data=df, order=orden_municipios)

# Añadir título y etiquetas
plt.title('Distribución de Precio por m² construido por Municipio (Ordenado por Mediana)')
plt.xlabel('Precio por m² construido')
plt.ylabel('Municipio')

# Ajustar el layout para que no se corten las etiquetas
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Opcional: Mostrar las medianas para verificar el orden
print("Medianas por municipio (ordenadas de mayor a menor):")
print(mediana_por_municipio)
# Out:
# Medianas por municipio (ordenadas de mayor a menor):
# municipio
# E    3151
# CH   2265
# A    1731
# C    1484
# B    1353
# D    1272
# G    1121
# F    1075
# Name: precio_por_m2_construido, dtype: float64

# %%
# Filtrar solo el municipio A
df_municipio_a = df[df['municipio'] == 'A']

# Calcular Q1, Q3 e IQR para identificar outliers
Q1 = df_municipio_a['precio_por_m2_construido'].quantile(0.25)
Q3 = df_municipio_a['precio_por_m2_construido'].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites para outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identificar outliers (valores fuera de los límites)
outliers = df_municipio_a[
    (df_municipio_a['precio_por_m2_construido'] < lower_bound) | 
    (df_municipio_a['precio_por_m2_construido'] > upper_bound)
]

# Ordenar por precio_por_m2_construido de mayor a menor para ver los outliers superiores
outliers_sorted = outliers.sort_values('precio_por_m2_construido', ascending=False)

# Mostrar los 4 outliers principales
print(f"Total de outliers en municipio A: {len(outliers)}")
print("\nLos 4 outliers con mayor precio por m²:")
print(outliers_sorted[['url', 'precio_por_m2_construido', 'precio']].head(4))

# Si prefieres solo las URLs
print("\nURLs de los 4 outliers principales:")
for idx, url in enumerate(outliers_sorted['url'].head(4), 1):
    print(f"{idx}. {url}")
# Out:
# Total de outliers en municipio A: 5
#
# Los 4 outliers con mayor precio por m²:
#                                                                                               url  \
# 959  https://www.casasymas.com.uy/propiedad/137357-casa-de-tres-dormitorios-en-venta-en-prado-009
# 916  https://www.casasymas.com.uy/propiedad/137356-casa-de-tres-dormitorios-en-venta-en-prado-010
# 566  https://www.casasymas.com.uy/propiedad/137355-casa-de-tres-dormitorios-en-venta-en-prado-014
# 551  https://www.casasymas.com.uy/propiedad/137351-casa-de-tres-dormitorios-en-venta-en-prado-005
#
#      precio_por_m2_construido  precio
# 959                     24250  388000
# 916                     23750  380000
# 566                     22812  365000
# 551                     21250  340000
#
# URLs de los 4 outliers principales:
# 1. https://www.casasymas.com.uy/propiedad/137357-casa-de-tres-dormitorios-en-venta-en-prado-009
# 2. https://www.casasymas.com.uy/propiedad/137356-casa-de-tres-dormitorios-en-venta-en-prado-010
# 3. https://www.casasymas.com.uy/propiedad/137355-casa-de-tres-dormitorios-en-venta-en-prado-014
# 4. https://www.casasymas.com.uy/propiedad/137351-casa-de-tres-dormitorios-en-venta-en-prado-005

# %% [markdown]
# ## Sacar Outliers dónde precio_por_m2_construido > 10,000

# %%
# Ver cuántas filas tienen precio_por_m2_construido > 10000
rows_to_remove = df[df['precio_por_m2_construido'] > 10000]
print(f"Filas a eliminar (precio_por_m2_construido > 10000): {len(rows_to_remove)}")

# Eliminar las filas donde precio_por_m2_construido > 10000
df = df[df['precio_por_m2_construido'] <= 10000]

print(f"Filas restantes después del filtrado: {len(df)}")
# Out:
# Filas a eliminar (precio_por_m2_construido > 10000): 5
# Filas restantes después del filtrado: 897

# %%
# Ver cuántas filas tienen precio_por_m2_construido > 10000
rows_to_remove = df[df['precio_por_m2_terreno'] > 10000]
print(f"Filas a eliminar (precio_por_m2_terreno > 10000): {len(rows_to_remove)}")

# Eliminar las filas donde precio_por_m2_construido > 10000
df = df[df['precio_por_m2_terreno'] <= 10000]

print(f"Filas restantes después del filtrado: {len(df)}")
# Out:
# Filas a eliminar (precio_por_m2_terreno > 10000): 24
# Filas restantes después del filtrado: 720

# %% [markdown]
# ## Sacar de nuevo el ranking para ver como quedo

# %%
# Calcular el precio promedio por m2 construido por municipio
precio_promedio_por_m2_construido = df.groupby('municipio')['precio_por_m2_construido'].mean()

# Calcular la cantidad de propiedades por municipio
cantidad_propiedades_por_municipio = df.groupby('municipio').size()

# Combinar ambos resultados en un DataFrame
resultado_m2_municipio = pd.DataFrame({
    'precio_promedio_por_m2': precio_promedio_por_m2_construido,
    'cantidad_propiedades': cantidad_propiedades_por_municipio
})

# Ordenar de mayor a menor por precio promedio por m2
resultado_m2_municipio = resultado_m2_municipio.sort_values(by='precio_promedio_por_m2', ascending=False)

# Mostrar el resultado
print("Ranking de precio promedio por m² construido por municipio (actualizado):")
print(resultado_m2_municipio)
# Out:
# Ranking de precio promedio por m² construido por municipio (actualizado):
#            precio_promedio_por_m2  cantidad_propiedades
# municipio
# E                            3120                   281
# CH                           2450                   144
# A                            1676                    63
# C                            1547                    68
# B                            1450                    80
# D                            1354                    27
# G                            1163                    41
# F                             978                    16

# %%
# Configurar pandas para mostrar números en formato decimal
pd.set_option('display.float_format', '{:.0f}'.format)

# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio_por_m2_construido'

# Calcular la mediana por municipio para ordenar
mediana_por_municipio = df.groupby('municipio')['precio_por_m2_construido'].median().sort_values(ascending=False)

# Obtener el orden de los municipios (de mayor a menor mediana)
orden_municipios = mediana_por_municipio.index.tolist()

# Crear el boxplot con municipios ordenados en el eje Y por mediana
plt.figure(figsize=(12, 8))
sns.boxplot(y='municipio', x='precio_por_m2_construido', data=df, order=orden_municipios)

# Añadir título y etiquetas
plt.title('Distribución de Precio por m² construido por Municipio (Ordenado por Mediana)')
plt.xlabel('Precio por m² construido')
plt.ylabel('Municipio')

# Ajustar el layout para que no se corten las etiquetas
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Configurar pandas para mostrar números en formato decimal
pd.set_option('display.float_format', '{:.0f}'.format)

# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'municipio' y 'precio_por_m2_terreno'

# Calcular la mediana por municipio para ordenar
mediana_por_municipio = df.groupby('municipio')['precio_por_m2_terreno'].median().sort_values(ascending=False)

# Obtener el orden de los municipios (de mayor a menor mediana)
orden_municipios = mediana_por_municipio.index.tolist()

# Crear el boxplot con municipios ordenados en el eje Y por mediana
plt.figure(figsize=(12, 8))
sns.boxplot(y='municipio', x='precio_por_m2_terreno', data=df, order=orden_municipios)

# Añadir título y etiquetas
plt.title('Distribución de Precio por m² de Terreno por Municipio (Ordenado por Mediana)')
plt.xlabel('Precio por m² de Terreno')
plt.ylabel('Municipio')

# Ajustar el layout para que no se corten las etiquetas
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Configurar pandas para mostrar números sin decimales
pd.set_option('display.float_format', '{:.0f}'.format)

# Asegúrate de que 'df' es tu DataFrame y tiene las columnas 'barrio' y 'precio_por_m2_construido'

# Calcular el precio promedio por m2 construido por barrio
precio_promedio_por_m2_construido_barrios = df.groupby('barrio')['precio_por_m2_construido'].mean()

precio_promedio_por_m2_construido_barrios = precio_promedio_por_m2_construido_barrios.sort_values(ascending=False)

# Mostrar el precio promedio por barrio
print(precio_promedio_por_m2_construido_barrios)
# Out:
# barrio
# san-nicolas              5327
# carrasco                 3358
# carrasco-norte           3137
# villa-dolores            2951
# punta-carretas           2759
# punta-gorda              2650
# pocitos                  2606
# parque-batlle            2504
# buceo                    2479
# malvin                   2282
# prado                    2155
# parque-rivera            2132
# barrio-sur               1976
# la-blanqueada            1956
# brazo-oriental           1890
# parque-rodo              1792
# atahualpa                1730
# tres-cruces              1680
# malvin-norte             1677
# jacinto-vera             1668
# cordon                   1631
# capurro                  1629
# la-figurita              1536
# punta-rieles             1524
# victoria                 1513
# union                    1487
# mercado-modelo           1484
# larranaga                1474
# cerrito                  1471
# la-teja                  1464
# villa-munoz              1404
# cerro                    1376
# sayago                   1365
# la-comercial             1352
# paso-molino              1349
# palermo                  1348
# aires-puros              1342
# perez-castellanos        1338
# centro                   1327
# bella-vista              1314
# manga                    1292
# goes                     1284
# aguada                   1279
# reducto                  1207
# colon                    1202
# villa-espanola           1193
# lezica                   1149
# belvedere                1147
# maronas                  1052
# piedras-blancas           999
# penarol                   983
# bolivar                   897
# paso-de-la-arena          880
# flor-de-maronas           871
# pajas-blancas             833
# conciliacion              822
# ituzaingo                 757
# ciudad-vieja              684
# nuevo-paris               604
# jardines-del-hipodromo    523
# villa-garcia              410
# Name: precio_por_m2_construido, dtype: float64

# %% [markdown]
# ## GRAFICO PRECIO POR M2

# %%
df.head()
# Out:
#                                                                                                                  url  \
# 0                https://www.casasymas.com.uy/propiedad/183266-casa-en-venta-de-4-dormitorios-en-carrasco-montevideo
# 1        https://www.casasymas.com.uy/propiedad/940-casa-en-venta-de-3-dormitorios-con-garage-en-carrasco-montevideo
# 2             https://www.casasymas.com.uy/propiedad/159162-casa-en-venta-de-2-dormitorios-en-tres-cruces-montevideo
# 3  https://www.casasymas.com.uy/propiedad/133140-casa-en-venta-en-barrio-san-nicolas-3-dormitorios-servicio-ref-1627
# 4               https://www.casasymas.com.uy/propiedad/205399-venta-buceo-casa-3-dormitorios-gran-fondo-barbacoa-gge
#
#    precio  Baños  Superficie  Superficie Construida  Superficie Terreno  \
# 0  850000      3         429                    256                 429
# 1  380000      3         130                    130                 150
# 2  119000      1         380                     62                 380
# 3 1780000      4         263                    263                1316
# 4  370000      3         497                    195                 497
#
#    Garage  Parrillero  Calefacción            Cocina  Año de Construcción  \
# 0       4           0            0   Cocina Definida                 2005
# 1       1           1            1  Cocina Integrada                 2024
# 2       0           0            0   Cocina Definida                 1960
# 3       3           1            1   Cocina Definida                 2006
# 4       1           0            0   Cocina Definida                 1989
#
#    Jardín  Piscina  Patio  Dormitorio       barrio municipio  \
# 0       1        0      0           4     carrasco         E
# 1       1        0      0           3     carrasco         E
# 2       0        0      0           2  tres-cruces         B
# 3       1        1      0           3  san-nicolas         E
# 4       1        0      0           3        buceo        CH
#
#    precio_por_m2_construido  precio_por_m2_terreno  precio_por_m2
# 0                      3320                   1981           1981
# 1                      2923                   2533           2923
# 2                      1919                    313            313
# 3                      6768                   1353           6768
# 4                      1897                    744            744

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate average price per m2 for constructed area and land by municipality
precio_m2_construido = df.groupby('municipio')['precio_por_m2_construido'].mean()
precio_m2_terreno = df.groupby('municipio')['precio_por_m2_terreno'].mean()

# Sort by municipio name
precio_m2_construido = precio_m2_construido.sort_index()
precio_m2_terreno = precio_m2_terreno.sort_index()

# Calculate common scale for both y-axes
min_val = min(precio_m2_construido.min(), precio_m2_terreno.min())
max_val = max(precio_m2_construido.max(), precio_m2_terreno.max())
# Add some padding
y_min = min_val * 0.9
y_max = max_val * 1.1

# Create figure and first axis
fig, ax1 = plt.subplots(figsize=(14, 7))

# First y-axis (left) - Precio m2 Construido
x = np.arange(len(precio_m2_construido.index))
ax1.bar(x - 0.2, precio_m2_construido.values, width=0.4, label='Precio m² Construido', 
        color='steelblue', alpha=0.8)
ax1.set_xlabel('Municipio', fontsize=12, fontweight='bold')
ax1.set_ylabel('Precio m² Construido (U$S)', fontsize=12, fontweight='bold', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')
ax1.set_xticks(x)
ax1.set_xticklabels(precio_m2_construido.index, rotation=45, ha='right')
ax1.set_ylim(y_min, y_max)  # Set same scale

# Second y-axis (right) - Precio m2 Terreno
ax2 = ax1.twinx()
ax2.bar(x + 0.2, precio_m2_terreno.values, width=0.4, label='Precio m² Terreno', 
        color='coral', alpha=0.8)
ax2.set_ylabel('Precio m² Terreno (U$S)', fontsize=12, fontweight='bold', color='coral')
ax2.tick_params(axis='y', labelcolor='coral')
ax2.set_ylim(y_min, y_max)  # Set same scale

# Title and legend
plt.title('Precio Promedio por m² por Municipio\n(Construido vs Terreno)', 
          fontsize=14, fontweight='bold', pad=20)

# Combine legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=10)

plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ## PRECIO POR M2 POR BARRIO
#
# * carrasco
# * carrasco-norte
# * pocitos
# * prado
# * malvin
# * punta-gorda
# * la-blanqueada
# * buceo

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the specific neighborhoods to analyze
barrios_seleccionados = [
    'carrasco',
    'carrasco-norte',
    'pocitos',
    'prado',
    'malvin',
    'punta-gorda',
    'la-blanqueada',
    'buceo'
]

# Filter data for selected neighborhoods
df_barrios = df[df['barrio'].isin(barrios_seleccionados)]

# Calculate average price per m2 for constructed area and land by neighborhood
precio_m2_construido = df_barrios.groupby('barrio')['precio_por_m2_construido'].mean()
precio_m2_terreno = df_barrios.groupby('barrio')['precio_por_m2_terreno'].mean()

# Reindex to maintain the order of barrios_seleccionados
precio_m2_construido = precio_m2_construido.reindex(barrios_seleccionados)
precio_m2_terreno = precio_m2_terreno.reindex(barrios_seleccionados)

# Calculate common scale for both y-axes
min_val = min(precio_m2_construido.min(), precio_m2_terreno.min())
max_val = max(precio_m2_construido.max(), precio_m2_terreno.max())
# Add some padding
y_min = min_val * 0.9 if not np.isnan(min_val) else 0
y_max = max_val * 1.1 if not np.isnan(max_val) else 1000

# Create figure and first axis
fig, ax1 = plt.subplots(figsize=(14, 7))

# First y-axis (left) - Precio m2 Construido
x = np.arange(len(barrios_seleccionados))
ax1.bar(x - 0.2, precio_m2_construido.values, width=0.4, label='Precio m² Construido', 
        color='steelblue', alpha=0.8)
ax1.set_xlabel('Barrio', fontsize=12, fontweight='bold')
ax1.set_ylabel('Precio m² Construido (U$S)', fontsize=12, fontweight='bold', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')
ax1.set_xticks(x)
ax1.set_xticklabels(barrios_seleccionados, rotation=45, ha='right')
ax1.set_ylim(y_min, y_max)  # Set same scale

# Second y-axis (right) - Precio m2 Terreno
ax2 = ax1.twinx()
ax2.bar(x + 0.2, precio_m2_terreno.values, width=0.4, label='Precio m² Terreno', 
        color='coral', alpha=0.8)
ax2.set_ylabel('Precio m² Terreno (U$S)', fontsize=12, fontweight='bold', color='coral')
ax2.tick_params(axis='y', labelcolor='coral')
ax2.set_ylim(y_min, y_max)  # Set same scale

# Title and legend
plt.title('Precio Promedio por m² por Barrio\n(Construido vs Terreno)', 
          fontsize=14, fontweight='bold', pad=20)

# Combine legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=10)

plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ## EXPORT DATASET

# %%
df.to_excel('datasets/FINAL_DATASET_CLEAN_POCOS_DATOS.xlsx')
