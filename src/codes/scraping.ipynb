# %% [markdown]
# ## WEB SCRAPING DIFERENTES SITIOS INMOBILIARIOS

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
base_url = "https://www.infocasas.com.uy/venta/apartamentos/montevideo/buceo-y-en-pocitos-y-en-punta-carretas-y-en-carrasco-y-en-centro/monoambiente-y-1-dormitorio-y-2-dormitorios/usados"

# Obtener número de páginas
response = requests.get(base_url)
soup = BeautifulSoup(response.content, "html.parser")

# Buscar la última página disponible
pagination_links = soup.select("a.ant-pagination-item-link, a.ant-pagination-item")
page_numbers = []

for link in pagination_links:
    text = link.get_text(strip=True)
    if text.isdigit():
        page_numbers.append(int(text))

npages = max(page_numbers) if page_numbers else 1  # fallback 1

# Recorremos una o más páginas
paginas = range(1, 5)  
all_links = []

for i in paginas:
    url = f"{base_url}/pagina{i}"
    print(f"Scrapeando: {url}")
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, "html.parser")

    # Obtener links con class="lc-data"
    links = [a['href'] for a in soup.select("a.lc-data") if len(a['href']) > 10]
    links = list(set(links))

    all_links.extend(links)

# Filtrar los que contienen "/apartamentos"
filtered_links = [link for link in all_links if "/apartamentos" not in link]

# Mostrar resultados
for link in filtered_links:
    print(f"LINKS SCRAPEADOS: {link}")
# Out:
# Scrapeando: https://www.infocasas.com.uy/venta/apartamentos/montevideo/buceo-y-en-pocitos-y-en-punta-carretas-y-en-carrasco-y-en-centro/monoambiente-y-1-dormitorio-y-2-dormitorios/usados/pagina1
# Scrapeando: https://www.infocasas.com.uy/venta/apartamentos/montevideo/buceo-y-en-pocitos-y-en-punta-carretas-y-en-carrasco-y-en-centro/monoambiente-y-1-dormitorio-y-2-dormitorios/usados/pagina2
# Scrapeando: https://www.infocasas.com.uy/venta/apartamentos/montevideo/buceo-y-en-pocitos-y-en-punta-carretas-y-en-carrasco-y-en-centro/monoambiente-y-1-dormitorio-y-2-dormitorios/usados/pagina3
# Scrapeando: https://www.infocasas.com.uy/venta/apartamentos/montevideo/buceo-y-en-pocitos-y-en-punta-carretas-y-en-carrasco-y-en-centro/monoambiente-y-1-dormitorio-y-2-dormitorios/usados/pagina4
# LINKS SCRAPEADOS: /venta-apto-en-edifi-de-categ-sobre-bvar-150-mts-2-dorm-2-banos-serv-calef-gge/192507870
# LINKS SCRAPEADOS: /venta-apartamento-punta-carretas-1dormitorio-garage/192523397
# LINKS SCRAPEADOS: /apartamento-de-dos-dormitorios-en-venta-en-punta-carretas-con-gge/192372642
# LINKS SCRAPEADOS: /venta-apartamento-toprres-del-puerto-2-dormitorios/192216423
# LINKS SCRAPEADOS: /venta-casa-buceo-2dormitorios-cochera-parrillero/192563849
# LINKS SCRAPEADOS: /venta-de-apartamento-al-frente-2-dormitorios-garage-doble-pocitos-nuevo/190955227
# LINKS SCRAPEADOS: /apartamento-de-estilo-amplios-ambientes-2-dormitorios-y-servicio/191700965
# LINKS SCRAPEADOS: /venta-apartamento-de-2-dormitorios-en-punta-carretas-a-pasos-del-parque-villa-biarritz/192576375
# LINKS SCRAPEADOS: /venta-monoambiente-pocitos-nuevo/192236790
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitorios-todo-al-frente-en-pocitos/192556339
# LINKS SCRAPEADOS: /venta-apartamento-con-renta-1-dormitorio-cgaraje-punta-carretas/192476238
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitorios
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitorios-en-pocitos/192195781
# LINKS SCRAPEADOS: /apartamento-en-venta-2-dormitorios-punta-carretas/191910363
# LINKS SCRAPEADOS: /vende-apartamento-en-pocitos-2-dormitorios-y-2-banos-y-garaje-y-piscina/192365495
# LINKS SCRAPEADOS: /venta-penthouse-2-dormitorios-2-banos-en-el-centro-piso-13-excelente-vista/192262274
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitrios-pocitos/192555281
# LINKS SCRAPEADOS: /apto-con-potencial/191111547
# LINKS SCRAPEADOS: /apartamento-en-venta-de-1-dormitorio-con-cochera-sobre-av-italia/192285903
# LINKS SCRAPEADOS: /venta-monoambiente-en-pocitos/191185707
# LINKS SCRAPEADOS: /palacio-siri-amplisimo/192166805
# LINKS SCRAPEADOS: /venta-de-apto-2-dorm-2-banos-garage-en-rambla-de-pocitos/192270383
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitorios-pocitos/192398052
# LINKS SCRAPEADOS: /venta-monoambiente-en-pocitos/191903951
# LINKS SCRAPEADOS: /venta-2-dormitorios-y-garaje-en-punta-carretas/191689359
# LINKS SCRAPEADOS: /venta-apartamento-1-dormitorio-al-frente-alquilado/191585114
# LINKS SCRAPEADOS: /venta-con-renta-de-apartamento-de-1-dormitorio-con-parrillero-en-deja-vu-pocitos/192537520
# LINKS SCRAPEADOS: /venta-apartamento-1-dormitorio-401-b-ventura-boulevard-buceo/190974640
# LINKS SCRAPEADOS: /monoambiente-amplio-en-venta/192389366
# LINKS SCRAPEADOS: /venta-apartamento-1-dormitorio-amueblado-sarmiento/192459324
# LINKS SCRAPEADOS: /venta-con-renta-de-apartamento-2-dormitorios-en-01-las-artes/190914056
# LINKS SCRAPEADOS: /venta-apartamento-1-dormitorio-con-terraza-al-frente-en-centro/190946492
# LINKS SCRAPEADOS: /apartamento-en-venta-de-2-dormitorios-c-cochera-en-puerto-buceo/191708090
# LINKS SCRAPEADOS: /venta-apartamento-con-renta-monoambiente-2-terrazas-y-garaje-en-pocitos/190886264
# LINKS SCRAPEADOS: /venta-apartamento-monoambiente-con-terraza-en-pocitos/192170199
# LINKS SCRAPEADOS: /venta-con-renta-de-amplio-monoambiente-con-cochera-en-pocitos/191372497
# LINKS SCRAPEADOS: /apartamento-2-dormitorios-centro-montevideo-con-renta-amenities/192548398
# LINKS SCRAPEADOS: /apartamento-en-venta-de-2-dormitorios/192492656
# LINKS SCRAPEADOS: /venta-de-apartamento-en-centro/192485932
# LINKS SCRAPEADOS: /venta-apartamento-monoambiente-con-patio-en-excelente-ubicacion/191254651
# LINKS SCRAPEADOS: /en-exclusiva-apto-de-un-dormitorio-en-venta-en-punta-carretas-con-inquilinos/192052417
# LINKS SCRAPEADOS: /apartamento-en-venta-de-2-dormitorios-c-cochera-en-pocitos/191718854
# LINKS SCRAPEADOS: /venta-apartamento-2-dormitorios-2-banos-pocitos/190943721
# LINKS SCRAPEADOS: /venta-apartamento-de-2-dormitorios-y-escritorio-en-punta-carretas-para-entrar/192470505
# LINKS SCRAPEADOS: /rambla-excelente-ubicacion-amplia-cochera-posibilidad-2-autos/192088201
# LINKS SCRAPEADOS: /massini-y-chucarro-proximo-a-rambla-amplio-al-frente-de-1-dormitorio/192382848

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import json

# %%
base = "https://www.infocasas.com.uy"

db = pd.DataFrame()
nocargados = []

full_url = base + link
print(f"[{i+1}] Procesando este link: {full_url}")

resp = requests.get(full_url)
soup = BeautifulSoup(resp.content, "html.parser")
html_text = soup.get_text()
# Out:
# [1] Procesando este link: https://www.infocasas.com.uy/venta-apto-en-edifi-de-categ-sobre-bvar-150-mts-2-dorm-2-banos-serv-calef-gge/192507870
# [2] Procesando este link: https://www.infocasas.com.uy/venta-apartamento-punta-carretas-1dormitorio-garage/192523397
# [3] Procesando este link: https://www.infocasas.com.uy/apartamento-de-dos-dormitorios-en-venta-en-punta-carretas-con-gge/192372642
# [4] Procesando este link: https://www.infocasas.com.uy/venta-apartamento
Procesando este link: https://www.infocasas.com.uy/venta-apartamento-2-dormitorios-2-banos-pocitos/190943721
# [82] Procesando este link: https://www.infocasas.com.uy/venta-apartamento-de-2-dormitorios-y-escritorio-en-punta-carretas-para-entrar/192470505
# [83] Procesando este link: https://www.infocasas.com.uy/rambla-excelente-ubicacion-amplia-cochera-posibilidad-2-autos/192088201
# [84] Procesando este link: https://www.infocasas.com.uy/massini-y-chucarro-proximo-a-rambla-amplio-al-frente-de-1-dormitorio/192382848
#
# Scrapeo finalizado.
# Departamentos cargados: 84
# No cargados: 0

# %%
# Precio
precio_elem = soup.select_one("span.ant-typography.price")
precio = precio_elem.get_text(strip=True) if precio_elem else None

print(precio)
# Out:
# U$S 159.500

# %%
# Título de la propiedad
titulo_elem = soup.select_one("h1.ant-typography.property-title")

titulo = titulo_elem.get_text(strip=True) if titulo_elem else None

print(titulo)
# Out:
# Massini Y Chucarro Próximo A Rambla Amplio Al Frente De 1 Dormitorio

# %%
technical_sheet = soup.select("span.ant-typography")
print(technical_sheet)
# Out:
# [<span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">2 Dorm.</span>, <span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">3<!-- --> Baño<!-- -->s</span>, <span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">130<!-- --> <!-- -->m²</span>, <span class="ant-typography price"><strong>U$S 370.000</strong></span>, <span class="ant-typography ant-typography-secondary operation_type">Precio de<!-- --> <!-- -->Venta</span>, <span class="ant-typography ant-typography-secondary commonExpenses">+ $ 20.000 gastos comunes</span>, <span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">2 Dorm.</span>, <span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">3<!-- --> Baño<!-- -->s</span>, <span class="ant-typography ant-typography-ellipsis ant-typography-ellipsis-single-line">130<!-- --> <!-- -->m²</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Referencia</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Tipo de Propiedad</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Zona</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Estado</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Disposición</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">Baños</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">M² edificados</span>, <span class="ant-typography ant-typography-secondary small">• </span>, <span class="ant-typography">M² de terraza</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Box / Deposito</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Dormitorio de servicio</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Balcón / Terraza</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Ascensor</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Agua Caliente Central</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Calefacción Central</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Gas por Cañería</span>, <span class="ant-typography ant-typography-secondary small">•</span>, <span class="ant-typography">Lavadero</span>, <span class="ant-typography">Precio promedio por m² de propiedades similares<!-- -->:<!-- --> <!-- -->U$S 3.030<!-- --> /m²</span>, <span class="ant-typography text"><strong>-6<!-- -->% <!-- -->por debajo<span aria-label="arrow-down" class="anticon anticon-arrow-down success-icon" role="img"><svg aria-hidden="true" data-icon="arrow-down" fill="currentColor" focusable="false" height="1em" viewbox="64 64 896 896" width="1em"><path d="M862 465.3h-81c-4.6 0-9 2-12.1 5.5L550 723.1V160c0-4.4-3.6-8-8-8h-60c-4.4 0-8 3.6-8 8v563.1L255.1 470.8c-3-3.5-7.4-5.5-12.1-5.5h-81c-6.8 0-10.5 8.1-6 13.2L487.9 861a31.96 31.96 0 0048.3 0L868 478.5c4.5-5.2.8-13.2-6-13.2z"></path></svg></span></strong></span>, <span class="ant-typography">Precio de venta para propiedades similares<!-- -->: <!-- -->U$S 235.000<br/></span>, <span class="ant-typography text"><strong>57<!-- -->% <!-- -->por arriba<span aria-label="arrow-up" class="anticon anticon-arrow-up error-icon" role="img"><svg aria-hidden="true" data-icon="arrow-up" fill="currentColor" focusable="false" height="1em" viewbox="64 64 896 896"  ...
